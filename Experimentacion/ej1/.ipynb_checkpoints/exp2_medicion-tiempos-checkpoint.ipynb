# %%
from PIL import Image
import colorsys
import subprocess 
import os
import sys
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Generación de prueba

# %%
def preparar_img(name):
    img = Image.open(os.path.join(image_path,name)).convert("L")
    width, height = img.size
    data = ""
    imgdata = list(img.getdata())
    for i in range(0,height):        
        indexes = range(i*width,i*width+width)
        data = data + " ".join([str(imgdata[x]) for x in indexes]) + "\n"
    input_text = f"{height} {width}\n{data}"
    return (height, width, input_text, img)
# def correr(image_name, k, metodo):
#     datos_img = preparar_img(image_name)
#     completado = subprocess.run(["../../Resolucion/bin/ej1", f"{metodo}", f"{k}"], stdout=subprocess.PIPE, input=datos_img[2], universal_newlines=True)
#     if completado.returncode != 0:
#         print(f"ERROR: El programa finalizo de forma incorrecta. Parametros usados: k={k} metodo={metodo}")

# %%
image_path = "../datos_entrada/ej1/"
csvFileName="./ej1_tiempos.csv"
testCases="testCases.in"
test_times = 10
images = {
        "test1.jpg": None
}
methods = [0,1,2]

kRange = range(500,6001,500)
for path in images:
    images[path] = preparar_img(path)

# %%
for k in kRange:
    for m in methods:
        for imgName,imgData in images.items():
            completado = subprocess.run(["../../Resolucion/bin/ej1", f"{m}", f"{k}"], stdout=subprocess.PIPE, input=imgData[2], universal_newlines=True)
            if completado.returncode != 0:
                print(f"ERROR: El programa finalizo de forma incorrecta. Parametros usados: k={k} metodo={metodo}")

# %%
csv = pandas.read_csv(csvFileName,header=None)
csv
# Out:
#                                            0     1           2
# 0                    DisjointSet con Arreglo  1000  7629.71000
# 1                    DisjointSet con Arreglo  1000  7582.30000
# 2                    DisjointSet con Arreglo  1000  7527.71000
# 3                    DisjointSet con Arreglo  1000  7919.28000
# 4                    DisjointSet con Arreglo  1000  7529.52000
# 5                    DisjointSet con Arreglo  1000  7560.86000
# 6                    DisjointSet con Arreglo  1000  7586.49000
# 7                    DisjointSet con Arreglo  1000  7591.38000
# 8                      DisjointSet con arbol  1000    10.35350
# 9                    DisjointSet con Arreglo  1000  7627.11000
# 10                     DisjointSet con arbol  1000     9.30203
# 11  DisjointSet con arbol y Path Compression  1000    12.81150
# 12  DisjointSet con arbol y Path Compression  1000    12.51690
# 13                   DisjointSet con Arreglo  1000  7629.84000
# 14                     DisjointSet con arbol  1000    10.69510
# 15                   DisjointSet con Arreglo  1000  7737.18000
# 16                     DisjointSet con arbol  1000    10.37030
# 17  DisjointSet con arbol y Path Compression  1000    13.52970
# 18  DisjointSet con arbol y Path Compression  1000    12.93320
# 19                   DisjointSet con Arreglo  1000  7595.19000
# 20                     DisjointSet con arbol  1000     9.99985
# 21                   DisjointSet con Arreglo  1000  7578.66000
# 22                     DisjointSet con arbol  1000     9.69495
# 23  DisjointSet con arbol y Path Compression  1000    12.82000
# 24  DisjointSet con arbol y Path Compression  1000    12.81560
# 25                   DisjointSet con Arreglo  1000  7514.40000
# 26                     DisjointSet con arbol  1000    10.11120
# 27                   DisjointSet con Arreglo  1000  7676.45000
# 28                     DisjointSet con arbol  1000     9.64608
# 29  DisjointSet con arbol y Path Compression  1000    12.85780
# ..                                       ...   ...         ...
# 69                   DisjointSet con Arreglo  2500  7806.52000
# 70                     DisjointSet con arbol  2500    10.98490
# 71  DisjointSet con arbol y Path Compression  2500    13.64910
# 72                   DisjointSet con Arreglo  3000  7790.95000
# 73                     DisjointSet con arbol  3000    11.78970
# 74  DisjointSet con arbol y Path Compression  3000    14.58880
# 75                   DisjointSet con Arreglo  3500  7696.08000
# 76                     DisjointSet con arbol  3500    11.38560
# 77  DisjointSet con arbol y Path Compression  3500    14.10150
# 78                   DisjointSet con Arreglo  4000  7684.02000
# 79                     DisjointSet con arbol  4000    12.16260
# 80  DisjointSet con arbol y Path Compression  4000    14.77580
# 81                   DisjointSet con Arreglo  4500  7974.83000
# 82                     DisjointSet con arbol  4500    12.08650
# 83  DisjointSet con arbol y Path Compression  4500    14.09860
# 84                   DisjointSet con Arreglo  5000  8070.26000
# 85                     DisjointSet con arbol  5000    14.13620
# 86  DisjointSet con arbol y Path Compression  5000    14.75130
# 87                   DisjointSet con Arreglo  5500  8304.70000
# 88                     DisjointSet con arbol  5500    12.36420
# 89  DisjointSet con arbol y Path Compression  5500    14.30020
# 90                   DisjointSet con Arreglo  6000  7939.81000
# 91                     DisjointSet con arbol  6000    11.56190
# 92  DisjointSet con arbol y Path Compression  6000    15.54260
# 93                   DisjointSet con Arreglo   500  7606.44000
# 94                     DisjointSet con arbol   500    11.50380
# 95  DisjointSet con arbol y Path Compression   500    14.45030
# 96                   DisjointSet con Arreglo  1000  7610.79000
# 97                     DisjointSet con arbol  1000    12.04740
# 98  DisjointSet con arbol y Path Compression  1000    18.13760
#
# [99 rows x 3 columns]

# %%
plt.clf()
for method in csv[0].unique():
    methodResults = csv[csv[0]==method]
    resultsByK = [np.median(methodResults[methodResults[1] == k].loc[:,2]) for k in kRange]
    plt.scatter(kRange,resultsByK,label=method)

        
plt.legend();
plt.xlabel("Valor de K")
plt.ylabel("Tiempo");
        
# fig = plt.gcf()
# # fig.savefig('imagenes/obj5/PDmejorqueMITM.png', dpi=100)
